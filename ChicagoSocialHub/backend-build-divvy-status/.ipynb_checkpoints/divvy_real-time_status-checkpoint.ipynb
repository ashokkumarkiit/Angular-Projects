# %%
##################################################################################################
##################################################################################################


### This file and the source code provided can be used only for the projects and assignments  
### of this course

### Last Edit by Dr. Atef Bader: 7/13/2019


##################################################################################################

# %% [markdown]
# ## Divvy
#
# **Divvy** is a bicycle sharing system in the City of Chicago.
#
# Click __[here](https://en.wikipedia.org/wiki/Divvy)__ to read more about **Divvy**
#
#
# Click __[here](https://www.divvybikes.com/)__ to visit the official website for **Divvy**

# %% [markdown]
# This script will send a heartbeat every 2 minutes to divvy to collect their stations status in the City of Chicago.

# %% [markdown]
# ### PostgreSQL
#
# We will collect the data from **Divvy** servers and store the data in a table on **PostgreSQL** server.
#
# This python script will send a heartbeat to Divvy every 2 minutes to retrieve the  status of the Divvy dock stations and store the data on PostgreSQL server.
#
# You need the package **psycopg2** to Connect to **PostgreSQL** server.
#
# Execute the **pip install** command from the command window to install  the package listed bove:
# - pip install psycopg2

# %%
import json
import requests
import datetime
import time
import os
import psycopg2
import pandas as pd
from urllib.request import urlopen
import json
import csv
from pprint import pprint
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT 
from datetime import datetime

# %%
from elasticsearch import Elasticsearch, helpers 

es = Elasticsearch()

# %%
def set_data(input_file, index_name = "divvy_station_logs", doc_type_name="log"):
    for line in input_file:
        
        yield {
            "_index": index_name,
            "_type": doc_type_name,
            "_source": line
            
        }

# %%
def load(es, input_file, **kwargs):
    success, _ = helpers.bulk(es, set_data(input_file, **kwargs))

# %%
# Get divvy statations status
# Status is returned as a json reply

# response = urlopen('https://feeds.divvybikes.com/stations/stations.json')

response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

# Extract the body of the reply
response_body = response.read()
response_stations_info = response_stations_info.read()

# Decode the format in json format
stations_json = json.loads(response_body.decode("utf-8"))
stations_info_json = json.loads(response_stations_info.decode("utf-8"))

# %%
pprint(stations_json)
# Out:
# {'data': {'stations': [{'eightd_active_station_services': [{'id': 'fff8cefb-8cbe-49cc-b70b-0b12f62df761'}],
#                         'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864730,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '211',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864282,
#                         'num_bikes_available': 17,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 22,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '2',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585819580,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 41,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '3',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585821402,
#                         'num_bikes_available': 16,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '4',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863471,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '5',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585832867,
#                         'num_bikes_available': 27,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '6',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585859967,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '7',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863263,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '9',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585854101,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '11',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585853804,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '12',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864566,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 20,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '13',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585821087,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '14',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864670,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '15',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864513,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '16',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864795,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '17',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585860451,
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '18',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863873,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '19',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585861021,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '20',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864831,
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '21',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585861005,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '22',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585843866,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '23',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863617,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '24',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585856706,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '25',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585862757,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 19,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '26',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585838071,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '27',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585848383,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '28',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864816,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '29',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864065,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '30',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863771,
#                         'num_bikes_available': 19,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '31',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585862858,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '32',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864637,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '33',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585844679,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '34',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585856839,
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 32,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '35',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863549,
#                         'num_bikes_available': 23,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '36',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585862824,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '37',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585862811,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 19,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '38',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585832334,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '39',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585860503,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '40',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863703,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 17,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '41',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863483,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '42',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585853723,
#                         'num_bikes_available': 19,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 24,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '43',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585860204,
#                         'num_bikes_available': 20,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '44',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585860637,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '45',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863031,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '46',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863295,
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '47',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585861597,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 29,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '48',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864734,
#                         'num_bikes_available': 34,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '49',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585858875,
#                         'num_bikes_available': 21,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '50',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863755,
#                         'num_bikes_available': 38,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '51',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864245,
#                         'num_bikes_available': 17,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '52',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863982,
#                         'num_bikes_available': 20,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '53',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864301,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '54',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585846117,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '55',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864503,
#                         'num_bikes_available': 18,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '56',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585860381,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '57',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585858098,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '58',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585862807,
#                         'num_bikes_available': 19,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '59',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585857825,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '60',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864556,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '61',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585821401,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 17,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '62',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864105,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '66',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863964,
#                         'num_bikes_available': 22,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '67',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585854710,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '68',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864477,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '69',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585860852,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '71',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863714,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 28,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '72',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863619,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '73',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864856,
#                         'num_bikes_available': 18,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '74',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864732,
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 32,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '75',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585818076,
#                         'num_bikes_available': 26,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '76',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864544,
#                         'num_bikes_available': 19,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '77',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585860369,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '80',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585860604,
#                         'num_bikes_available': 38,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '81',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863100,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '84',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585859612,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 20,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '85',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585861282,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '86',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863360,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '87',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585861897,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '88',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585862754,
#                         'num_bikes_available': 26,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '89',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864255,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 34,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '90',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864785,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '91',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585862471,
#                         'num_bikes_available': 8,
# ...
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863322,
#                         'num_bikes_available': 28,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '623',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585862710,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '624',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585861157,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '625',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585845588,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '626',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585860836,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '627',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863957,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '628',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585860606,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '630',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585861613,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '631',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585859953,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '635',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585851552,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '636',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863679,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '638',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585854020,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '639',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585821401,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '642',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585820484,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '645',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585820484,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '647',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585821088,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '652',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585821088,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '653',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864578,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '657',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585862882,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '659',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585864182,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '660',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585821403,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '661',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585821403,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '662',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585855988,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '663',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585819881,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '665',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585863489,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '666',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585856971,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '672',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1585861116,
#                         'num_bikes_available': 21,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '673',
#                         'station_status': 'active'}]},
#  'last_updated': 1585864900,
#  'ttl': 300}

# %%
pprint(stations_info_json)
# Out:
# {'data': {'stations': [{'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [{'bikes_availability': 'UNLIMITED',
#                                                      'description': '',
#                                                      'docks_availability': 'UNLIMITED',
#                                                      'id': 'fff8cefb-8cbe-49cc-b70b-0b12f62df761',
#                                                      'link_for_more_info': 'https://www.divvybikes.com/valet',
#                                                      'name': 'Valet',
#                                                      'schedule_description': 'Monday-Friday',
#                                                      'service_type': 'ATTENDED_SERVICE'}],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a7dc8c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.894448,
#                         'lon': -87.622663,
#                         'name': 'St. Clair St & Erie St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13016',
#                         'station_id': '211',
#                         'station_type': 'classic'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a36d9e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87651122881695,
#                         'lon': -87.62054800987242,
#                         'name': 'Buckingham Fountain',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15541',
#                         'station_id': '2',
#                         'station_type': 'classic'},
#                        {'capacity': 55,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a37378-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.86722595682,
#                         'lon': -87.6153553902,
#                         'name': 'Shedd Aquarium',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15544',
#                         'station_id': '3',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a378ca-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.856268,
#                         'lon': -87.613348,
#                         'name': 'Burnham Harbor',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15545',
#                         'station_id': '4',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a37e26-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.874053,
#                         'lon': -87.627716,
#                         'name': 'State St & Harrison St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'SL-007',
#                         'station_id': '5',
#                         'station_type': 'classic'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a38363-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.886976,
#                         'lon': -87.612813,
#                         'name': 'Dusable Harbor',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000064',
#                         'station_id': '6',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3888b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88634906269,
#                         'lon': -87.6175165471,
#                         'name': 'Field Blvd & South Water St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15534',
#                         'station_id': '7',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a39301-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.82879201994,
#                         'lon': -87.6806044594,
#                         'name': 'Leavitt St & Archer Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000068',
#                         'station_id': '9',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3983e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.76663823695,
#                         'lon': -87.5764501141,
#                         'name': 'Jeffery Blvd & 71st St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000018',
#                         'station_id': '11',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a39d55-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.7664094567,
#                         'lon': -87.5656875719,
#                         'name': 'South Shore Dr & 71st St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000002',
#                         'station_id': '12',
#                         'station_type': 'classic'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3a282-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.932418,
#                         'lon': -87.652705,
#                         'name': 'Wilton Ave & Diversey Pkwy',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000014',
#                         'station_id': '13',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3a7b4-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.858086,
#                         'lon': -87.651073,
#                         'name': 'Morgan St & 18th St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13163',
#                         'station_id': '14',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3ace6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.858166,
#                         'lon': -87.656495,
#                         'name': 'Racine Ave & 18th St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13164',
#                         'station_id': '15',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3b202-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.910337,
#                         'lon': -87.670072,
#                         'name': 'Paulina Ave & North Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000037',
#                         'station_id': '16',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3b731-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.903119,
#                         'lon': -87.673935,
#                         'name': 'Honore St & Division St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000034',
#                         'station_id': '17',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3bc53-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.883132,
#                         'lon': -87.637321,
#                         'name': 'Wacker Dr & Washington St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000072',
#                         'station_id': '18',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3c174-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.868968,
#                         'lon': -87.659141,
#                         'name': 'Throop (Loomis) St & Taylor St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13139',
#                         'station_id': '19',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3c696-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.910522,
#                         'lon': -87.653106,
#                         'name': 'Sheffield Ave & Kingsbury St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13154',
#                         'station_id': '20',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3cbac-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87772613,
#                         'lon': -87.65478743,
#                         'name': 'Aberdeen St & Jackson Blvd',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13157',
#                         'station_id': '21',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3d1b8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8694821,
#                         'lon': -87.6554864,
#                         'name': 'May St & Taylor St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13160',
#                         'station_id': '22',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3d6f0-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.902924,
#                         'lon': -87.637715,
#                         'name': 'Orleans St & Elm St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000006',
#                         'station_id': '23',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3dc37-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89184737210993,
#                         'lon': -87.62058019638062,
#                         'name': 'Fairbanks Ct & Grand Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000003',
#                         'station_id': '24',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3e158-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89766,
#                         'lon': -87.62351,
#                         'name': 'Michigan Ave & Pearson St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13034',
#                         'station_id': '25',
#                         'station_type': 'classic'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3e67b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.890359,
#                         'lon': -87.617532,
#                         'name': 'McClurg Ct & Illinois St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000013',
#                         'station_id': '26',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3eb9a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.91021,
#                         'lon': -87.6435,
#                         'name': 'Larrabee St & North Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000008',
#                         'station_id': '27',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3f0c6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.91468,
#                         'lon': -87.64332,
#                         'name': 'Larrabee St & Menomonee St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000007',
#                         'station_id': '28',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3f5e9-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.90068,
#                         'lon': -87.6626,
#                         'name': 'Noble St & Milwaukee Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13290',
#                         'station_id': '29',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3fb5d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.899643,
#                         'lon': -87.6677,
#                         'name': 'Ashland Ave & Augusta Blvd',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13248',
#                         'station_id': '30',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a40088-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.896746973093805,
#                         'lon': -87.63566762208939,
#                         'name': 'Franklin St & Chicago Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13017',
#                         'station_id': '31',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a405a1-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87464,
#                         'lon': -87.65703,
#                         'name': 'Racine Ave & Congress Pkwy',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000025',
#                         'station_id': '32',
#                         'station_type': 'classic'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a40ad8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.877181,
#                         'lon': -87.627844,
#                         'name': 'State St & Van Buren St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000035',
#                         'station_id': '33',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41004-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9267559875,
#                         'lon': -87.6344287848,
#                         'name': 'Cannon Dr & Fullerton Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13124',
#                         'station_id': '34',
#                         'station_type': 'classic'},
#                        {'capacity': 47,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41526-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.892278,
#                         'lon': -87.612043,
#                         'name': 'Streeter Dr & Grand Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13022',
#                         'station_id': '35',
#                         'station_type': 'classic'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41af5-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8777079559,
#                         'lon': -87.6353211408,
#                         'name': 'Franklin St & Jackson Blvd',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000025',
#                         'station_id': '36',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4203a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8793563587,
#                         'lon': -87.6297910363,
#                         'name': 'Dearborn St & Adams St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000005',
#                         'station_id': '37',
#                         'station_type': 'classic'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42574-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88602082773,
#                         'lon': -87.6308760584,
#                         'name': 'Clark St & Lake St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000012',
#                         'station_id': '38',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42a93-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87947235235,
#                         'lon': -87.6256886059,
#                         'name': 'Wabash Ave & Adams St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000015',
#                         'station_id': '39',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42fa7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87934437346,
#                         'lon': -87.6319852213,
#                         'name': 'LaSalle St & Adams St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000034',
#                         'station_id': '40',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a434ce-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87207763285,
#                         'lon': -87.6295437729,
#                         'name': 'Federal St & Polk St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'SL-008',
#                         'station_id': '41',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a43a25-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.852619,
#                         'lon': -87.626488,
#                         'name': 'Wabash Ave & Cermak Rd',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000001',
#                         'station_id': '42',
#                         'station_type': 'classic'},
#                        {'capacity': 43,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a43f48-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8839840647265,
#                         'lon': -87.6246839761734,
#                         'name': 'Michigan Ave & Washington St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13001',
#                         'station_id': '43',
#                         'station_type': 'classic'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a44476-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8847302006,
#                         'lon': -87.6277335692,
#                         'name': 'State St & Randolph St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000029',
#                         'station_id': '44',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4499f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.876243,
#                         'lon': -87.624426,
#                         'name': 'Michigan Ave & Ida B Wells Dr',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000010',
#                         'station_id': '45',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a44ec7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89993001,
#                         'lon': -87.63443007,
#                         'name': 'Wells St & Walton St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000011',
#                         'station_id': '46',
#                         'station_type': 'classic'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a453fa-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.889187,
#                         'lon': -87.627754,
#                         'name': 'State St & Kinzie St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13050',
#                         'station_id': '47',
#                         'station_type': 'classic'},
#                        {'capacity': 43,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4591a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.897764,
#                         'lon': -87.642884,
#                         'name': 'Larrabee St & Kingsbury St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000009',
#                         'station_id': '48',
#                         'station_type': 'classic'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a45e3b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.881319815,
#                         'lon': -87.6295209193,
#                         'name': 'Dearborn St & Monroe St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000006',
#                         'station_id': '49',
#                         'station_type': 'classic'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46361-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8759326655,
#                         'lon': -87.6305845355,
#                         'name': 'Clark St & Ida B Wells Dr',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000009',
#                         'station_id': '50',
#                         'station_type': 'classic'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46896-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.884576228,
#                         'lon': -87.63188991,
#                         'name': 'Clark St & Randolph St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000030',
#                         'station_id': '51',
#                         'station_type': 'classic'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46e71-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.886024,
#                         'lon': -87.624117,
#                         'name': 'Michigan Ave & Lake St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000011',
#                         'station_id': '52',
#                         'station_type': 'classic'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4739d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.894722,
#                         'lon': -87.634362,
#                         'name': 'Wells St & Huron St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000012',
#                         'station_id': '53',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a478c9-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.896362458,
#                         'lon': -87.6540612729,
#                         'name': 'Ogden Ave & Chicago Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000020',
#                         'station_id': '54',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a47dde-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.867324,
#                         'lon': -87.648625,
#                         'name': 'Halsted St & Roosevelt Rd',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000017',
#                         'station_id': '55',
#                         'station_type': 'classic'},
# ...
#                         'external_id': 'a3b3a0c8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.890028,
#                         'lon': -87.636618,
#                         'name': 'Orleans St & Hubbard St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '636',
#                         'station_id': '636',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b41f78-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87811603010527,
#                         'lon': -87.63983845710754,
#                         'name': 'Clinton St & Jackson Blvd',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '638',
#                         'station_id': '638',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b424f6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.965845,
#                         'lon': -87.645361,
#                         'name': 'Lakefront Trail & Wilson Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '639',
#                         'station_id': '639',
#                         'station_type': 'classic'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b43478-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.894745,
#                         'lon': -87.756895,
#                         'name': 'Latrobe Ave & Chicago Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '642',
#                         'station_id': '642',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b443ce-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.826712,
#                         'lon': -87.683144,
#                         'name': 'Archer (Damen) Ave & 37th St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '18022',
#                         'station_id': '645',
#                         'station_type': 'classic'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b44eba-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.786691,
#                         'lon': -87.655859,
#                         'name': 'Elizabeth St & 59th St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '647',
#                         'station_id': '647',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b46866-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.766,
#                         'lon': -87.611726,
#                         'name': 'Rhodes Ave & 71st St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '652',
#                         'station_id': '652',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b46d7b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.780595,
#                         'lon': -87.584846,
#                         'name': 'Cornell Dr & Hayes Dr',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '653',
#                         'station_id': '653',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b481e1-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.899181,
#                         'lon': -87.6722,
#                         'name': 'Wood St & Augusta Blvd',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '657',
#                         'station_id': '657',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b48c07-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.895501,
#                         'lon': -87.682017,
#                         'name': 'Leavitt St & Chicago Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '18058',
#                         'station_id': '659',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b49122-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.004583,
#                         'lon': -87.661406,
#                         'name': 'Sheridan Rd & Columbia Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '660',
#                         'station_id': '660',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4963f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.057044,
#                         'lon': -87.686554,
#                         'name': 'Evanston Civic Center',
#                         'region_id': '35',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '661',
#                         'station_id': '661',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b49b4c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.023463,
#                         'lon': -87.699595,
#                         'name': 'Dodge Ave & Mulford St',
#                         'region_id': '35',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '662',
#                         'station_id': '662',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4a05c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.064854,
#                         'lon': -87.715297,
#                         'name': 'Lincolnwood Dr & Central St',
#                         'region_id': '35',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'E014',
#                         'station_id': '663',
#                         'station_type': 'classic'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4aa91-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.747363,
#                         'lon': -87.580046,
#                         'name': 'South Chicago Ave & Elliot Ave',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '665',
#                         'station_id': '665',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4afb6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.907221,
#                         'lon': -87.655618,
#                         'name': 'Cherry Ave & Blackhawk St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '18069',
#                         'station_id': '666',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': '8995498f-1209-4b06-9317-01cd695b3b61',
#                         'has_kiosk': True,
#                         'lat': 41.89102331025185,
#                         'lon': -87.63547986745834,
#                         'name': 'Franklin St & Illinois St',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'RN-',
#                         'station_id': '672',
#                         'station_type': 'classic'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': '9e1fbaaa-e872-4505-ada6-5080e62bef77',
#                         'has_kiosk': True,
#                         'lat': 41.92393131136619,
#                         'lon': -87.63582453131676,
#                         'name': 'Lincoln Park Conservatory',
#                         'rental_methods': ['TRANSITCARD', 'KEY', 'CREDITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'LP-',
#                         'station_id': '673',
#                         'station_type': 'classic'}]},
#  'last_updated': 1585864900,
#  'ttl': 300}

# %%
#Use default user name as postgres ,if username root is not working

db_connection = psycopg2.connect(host='127.0.0.1',dbname="postgres", user="postgres" , password="ashok0898")

# %%
db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT) 

cursor = db_connection.cursor()

# %%
    # Only once you need to create the postgis extension.
  #  cursor.execute("CREATE DATABASE chicago_divvy_stations_status;")

db_connection = psycopg2.connect(host='127.0.0.1',dbname="chicago_divvy_stations_status", user="postgres" , password="ashok0898")


cursor = db_connection.cursor()

# %%
# Only once you need to create the postgis extension.
# Comment the following line if you already created the postgis extension
# Add it manually in Postgres ,if there is issue with this query

cursor.execute("CREATE EXTENSION postgis;")
# Out:
# ---------------------------------------------------------------------------
# DuplicateObject                           Traceback (most recent call last)
# <ipython-input-13-040da5064f86> in <module>
#       3 # Add it manually in Postgres ,if there is issue with this query
#       4
# ----> 5 cursor.execute("CREATE EXTENSION postgis;")
#
# DuplicateObject: extension "postgis" already exists

# %%
db_connection.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS divvy_stations_realtime_status")

# %%
db_connection.commit()

# %%
cursor.execute("""CREATE TABLE divvy_stations_realtime_status(
                altitude FLOAT,
                availableBikes INTEGER,
                availableDocks INTEGER,
                city TEXT,
                id INTEGER,
                is_renting BOOLEAN,
                kioskType TEXT,
                landMark TEXT,
                lastCommunicationTime timestamp,
                latitude FLOAT,
                location TEXT,
                longitude FLOAT,
                postalCode INTEGER,
                stAddress1 TEXT,
                stAddress2 TEXT,
                stationName TEXT,
                status TEXT,
                statusKey INTEGER,
                statusValue TEXT,
                testStation BOOLEAN,
                totalDocks INTEGER,
                Where_IS GEOGRAPHY);""")

# %%
db_connection.commit()

# %% [markdown]
# ### The following is the Heartbeat Loop - Pulls data from divvy every 2 minutes in order to get realtime updates for the different divvy stations

# %%
while True:
    # Get divvy statations status
    # Status is returned as a json reply

    response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

    response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

    # Extract the body of the reply
    response_body = response.read()
    response_stations_info = response_stations_info.read()

    # Decode the format in json format
    stations_json = json.loads(response_body.decode("utf-8"))
    stations_info_json = json.loads(response_stations_info.decode("utf-8"))
    
    
    stations_dictionary = stations_json['data']
    stations_info_dictionary = stations_info_json['data']
    
    # load data file into a dataframe
    df__stations = pd.DataFrame(stations_dictionary['stations'])
    df__stations_info = pd.DataFrame(stations_info_dictionary['stations'])
    
    divvy_stations_realtime_status = pd.DataFrame(columns=[
                'altitude',
                'availableBikes',
                'availableDocks',
                'city',
                'id',
                'is_renting',
                'kioskType',
                'landMark',
                'lastCommunicationTime',
                'latitude',
                'location',
                'longitude',
                'postalCode',
                'stAddress1',
                'stAddress2',
                'stationName',
                'status',
                'statusKey',
                'statusValue',
                'testStation',
                'totalDocks' ])
    
    for x in range(len(df__stations.index)):
        has_kiosk = df__stations_info['has_kiosk'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]
        row = [
            int(0),
            int(df__stations['num_bikes_available'].iloc[x]),
            int(df__stations['num_docks_available'].iloc[x]),
            'Chicago',
            int(df__stations['station_id'].iloc[x]),
            bool(df__stations['is_renting'].iloc[x]),
            has_kiosk,
            'Chicago',
            datetime.strptime(time.ctime(int(df__stations['last_reported'].iloc[x])), "%a %b %d %H:%M:%S %Y").strftime("%Y-%m-%d %H:%M:%S"),
            float(df__stations_info['lat'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]),
            'Chicago',
            float(df__stations_info['lon'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]),
            60602,
            'Chicago',
            'Chicago',
            df__stations_info['name'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0],
            'IN_SERVICE',
            1,
            'IN_SERVICE',
            False,
            int(df__stations_info['capacity'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0])]
    
        divvy_stations_realtime_status.loc[len(divvy_stations_realtime_status)] = row

        
    divvy_stations_realtime_status['altitude'] = divvy_stations_realtime_status['altitude'].astype(float)
    divvy_stations_realtime_status['availableBikes'] = divvy_stations_realtime_status['availableBikes'].astype(int)
    divvy_stations_realtime_status['availableDocks'] = divvy_stations_realtime_status['availableDocks'].astype(int)
    divvy_stations_realtime_status['city'] = divvy_stations_realtime_status.city.astype(str)
    divvy_stations_realtime_status['id'] = divvy_stations_realtime_status['id'].astype(int)
    divvy_stations_realtime_status['is_renting'] = divvy_stations_realtime_status['is_renting'].astype(bool)
    divvy_stations_realtime_status['kioskType'] = divvy_stations_realtime_status['kioskType'].astype(str)
    divvy_stations_realtime_status['landMark'] = divvy_stations_realtime_status['landMark'].astype(str)
    divvy_stations_realtime_status['lastCommunicationTime'] = divvy_stations_realtime_status['lastCommunicationTime'].astype(str)
    divvy_stations_realtime_status['latitude'] = divvy_stations_realtime_status['latitude'].astype(float)
    divvy_stations_realtime_status['location'] = divvy_stations_realtime_status['location'].astype(str)
    divvy_stations_realtime_status['longitude'] = divvy_stations_realtime_status['longitude'].astype(float)
    divvy_stations_realtime_status['postalCode'] = divvy_stations_realtime_status['postalCode'].astype(int)
    divvy_stations_realtime_status['stAddress1'] = divvy_stations_realtime_status['stAddress1'].astype(str)
    divvy_stations_realtime_status['stAddress2'] = divvy_stations_realtime_status['stAddress2'].astype(str)
    divvy_stations_realtime_status['stationName'] = divvy_stations_realtime_status['stationName'].astype(str)
    divvy_stations_realtime_status['status'] = divvy_stations_realtime_status['status'].astype(str)
    divvy_stations_realtime_status['statusKey'] = divvy_stations_realtime_status['statusKey'].astype(int)
    divvy_stations_realtime_status['statusValue'] = divvy_stations_realtime_status['statusValue'].astype(str)
    divvy_stations_realtime_status['testStation'] = divvy_stations_realtime_status['testStation'].astype(bool)
    divvy_stations_realtime_status['totalDocks'] = divvy_stations_realtime_status['totalDocks'].astype(int)
    
    # lets store our data subset into a file
    # This way you have a copy of data stored in a file 
    # that you could use in case you want to debug a problem on the orginal data received

    divvy_stations_realtime_status.to_csv('divvy_stations_status.csv',sep=',', encoding='utf-8', index=False)
    
    # delete existing data in the table
    cursor.execute("DELETE FROM divvy_stations_realtime_status")
    db_connection.commit()

    
    # Now we will connect to the database and store divvy data
    with open('divvy_stations_status.csv', 'r') as f:
        reader = csv.reader(f)
        next(reader)  # Skip the header row.
        for row in reader:
            cursor.execute( "INSERT INTO divvy_stations_realtime_status VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)", row)

    
    
    db_connection.commit()
    
    cursor.execute("UPDATE divvy_stations_realtime_status SET Where_IS = ST_POINT(latitude,longitude);")
    db_connection.commit()
    
    
    # Now we will connect to ElasticSearch database and store divvy data
    divvy_stations_realtime_status = divvy_stations_realtime_status.to_json(orient='records')
    divvy_stations_realtime_status = json.loads(divvy_stations_realtime_status)
    load(es,divvy_stations_realtime_status)
    
    
    # Sleep for 3 minutes; divvy updates its stations status every 2 minutes
