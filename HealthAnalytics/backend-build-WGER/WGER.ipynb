# %%
import json
import requests
import datetime
import time
import os
import psycopg2
import pandas as pd
from urllib.request import urlopen
import json
import csv
from pprint import pprint
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT 
from datetime import datetime
import io
import numpy as np

# %%
#Use default user name as postgres ,if username root is not working

db_connection = psycopg2.connect(host='127.0.0.1',dbname="postgres", user="postgres" , password="root")

# %%
db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT) 

cursor = db_connection.cursor()

# %%
# Only once you need to create the postgis extension.
#cursor.execute("CREATE DATABASE UML_PROJECT;")
db_connection.commit()

db_connection = psycopg2.connect(host='127.0.0.1',dbname="uml_project", user="postgres" , password="ashok0898")


cursor = db_connection.cursor()

# %%
db_connection.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS language")
cursor.execute("DROP TABLE IF EXISTS exercisecategory")
cursor.execute("DROP TABLE IF EXISTS exercise")
cursor.execute("DROP TABLE IF EXISTS exerciseimage")
cursor.execute("DROP TABLE IF EXISTS muscle")
# Maintain the mapping of exercise and Muscle.
cursor.execute("DROP TABLE IF EXISTS map_exercise_muscle")
cursor.execute("DROP TABLE IF EXISTS equipment")
# Maintain the mapping of exercise and equipment
cursor.execute("DROP TABLE IF EXISTS map_exercise_equipment")
cursor.execute("DROP TABLE IF EXISTS ingredient")
cursor.execute("DROP TABLE IF EXISTS ingredientweightunit")

db_connection.commit()

cursor.execute("""CREATE TABLE language(
                id INTEGER,
                short_name TEXT,
                full_name TEXT);""")

cursor.execute("""CREATE TABLE exercisecategory(
                id INTEGER,
                name TEXT);""")

cursor.execute("""CREATE TABLE exercise(
                id INTEGER,
                status TEXT,
                description TEXT,
                name TEXT,
                name_original TEXT,
                creation_date TEXT,
                category INTEGER,
                language INTEGER
                );""")

cursor.execute("""CREATE TABLE exerciseimage(
                id INTEGER,
                status TEXT,
                image TEXT,
                is_main BOOLEAN,
                exercise INTEGER
                );""")

cursor.execute("""CREATE TABLE muscle(
                id INTEGER,
                name TEXT,
                is_front BOOLEAN
                );""")

cursor.execute("""CREATE TABLE map_exercise_muscle(
                ex_id INTEGER,
                mu_id INTEGER
                );""")

cursor.execute("""CREATE TABLE equipment(
                id INTEGER,
                name TEXT
                );""")

cursor.execute("""CREATE TABLE map_exercise_equipment(
                ex_id INTEGER,
                eq_id INTEGER
                );""")


cursor.execute("""CREATE TABLE ingredient(
                id INTEGER,
                status TEXT,
                name TEXT,
                energy INTEGER,
                protein TEXT,
                carbohydrates TEXT,
                carbohydrates_sugar TEXT,
                fat TEXT,
                fat_saturated TEXT,
                fibres TEXT,
                sodium TEXT,
                language INTEGER);""")

cursor.execute("""CREATE TABLE ingredientweightunit(
                id INTEGER,
                gram INTEGER,
                amount TEXT,
                ingredient INTEGER,
                unit INTEGER);""")

# %%
db_connection.commit()

# %% [markdown]
# ### Insert to - language TABLE

# %%
url="http://wger.de/api/v2/language/?format=json"
response = urlopen(url)

# Extract the body of the reply
response_body = response.read()

# Decode the format in json format
languages = json.loads(response_body.decode("utf-8"))

df_languages = pd.DataFrame(languages['results'])

df_languages.to_csv('languages.csv',sep=',', encoding='utf-8', index=False)

# delete existing data in the table
cursor.execute("DELETE FROM language")
db_connection.commit()

# Now we will connect to the database and store language data
with open('languages.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip the header row.
    for row in reader:
        cursor.execute( "INSERT INTO language VALUES (%s, %s, %s)", row)
db_connection.commit()
print("Data inserted successfully to language table")
# Out:
# Data inserted successfully to language table

# %% [markdown]
# ### Insert to - exercisecategory TABLE

# %%
url="http://wger.de/api/v2/exercisecategory/?format=json"
response = urlopen(url)

# Extract the body of the reply
response_body = response.read()

# Decode the format in json format
exercise_category = json.loads(response_body.decode("utf-8"))

df_exercise_category = pd.DataFrame(exercise_category['results'])

df_exercise_category.to_csv('exercise_category.csv',sep=',', encoding='utf-8', index=False)

# delete existing data in the table
cursor.execute("DELETE FROM exercisecategory")
db_connection.commit()

# Now we will connect to the database and store exercisecategory data
with open('exercise_category.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip the header row.
    for row in reader:
        cursor.execute( "INSERT INTO exercisecategory VALUES (%s, %s)", row)
db_connection.commit()
print("Data inserted successfully to exercisecategory table")
# Out:
# Data inserted successfully to exercisecategory table

# %% [markdown]
# ### Insert to - exercise TABLE

# %%
url="http://wger.de/api/v2/exercise/?format=json"
response = urlopen(url)
print(url)

# Extract the body of the reply
response_body = response.read()

# Decode the format in json format
exercises = json.loads(response_body.decode("utf-8"))

exercises_dict = exercises['next']

df_exercises = pd.DataFrame(exercises['results'])
        
list_df = []
list_df.append(df_exercises)
while exercises_dict != None:
    print(exercises_dict)
    response = urlopen(exercises_dict)
    response_body = response.read()
    exercises = json.loads(response_body.decode("utf-8"))
    list_df.append(pd.DataFrame(exercises['results']))
    #df_exercises.append(pd.DataFrame(exercises['results']))
    #print(len(df_exercises))
    exercises_dict = exercises['next']
df_all_exercises = pd.concat(list_df, axis=0, join='outer', ignore_index=False)
# Out:
# http://wger.de/api/v2/exercise/?format=json
# http://wger.de/api/v2/exercise/?format=json&page=2
# http://wger.de/api/v2/exercise/?format=json&page=3
# http://wger.de/api/v2/exercise/?format=json&page=4
# http://wger.de/api/v2/exercise/?format=json&page=5
# http://wger.de/api/v2/exercise/?format=json&page=6
# http://wger.de/api/v2/exercise/?format=json&page=7
# http://wger.de/api/v2/exercise/?format=json&page=8
# http://wger.de/api/v2/exercise/?format=json&page=9
# http://wger.de/api/v2/exercise/?format=json&page=10
# http://wger.de/api/v2/exercise/?format=json&page=11
# http://wger.de/api/v2/exercise/?format=json&page=12
# http://wger.de/api/v2/exercise/?format=json&page=13
# http://wger.de/api/v2/exercise/?format=json&page=14
# http://wger.de/api/v2/exercise/?format=json&page=15
# http://wger.de/api/v2/exercise/?format=json&page=16
# http://wger.de/api/v2/exercise/?format=json&page=17
# http://wger.de/api/v2/exercise/?format=json&page=18
# http://wger.de/api/v2/exercise/?format=json&page=19
# http://wger.de/api/v2/exercise/?format=json&page=20
# http://wger.de/api/v2/exercise/?format=json&page=21
# http://wger.de/api/v2/exercise/?format=json&page=22
# http://wger.de/api/v2/exercise/?format=json&page=23
# http://wger.de/api/v2/exercise/?format=json&page=24
# http://wger.de/api/v2/exercise/?format=json&page=25
# http://wger.de/api/v2/exercise/?format=json&page=26
# http://wger.de/api/v2/exercise/?format=json&page=27
# http://wger.de/api/v2/exercise/?format=json&page=28
# http://wger.de/api/v2/exercise/?format=json&page=29
# http://wger.de/api/v2/exercise/?format=json&page=30
# http://wger.de/api/v2/exercise/?format=json&page=31
# http://wger.de/api/v2/exercise/?format=json&page=32
# http://wger.de/api/v2/exercise/?format=json&page=33
# http://wger.de/api/v2/exercise/?format=json&page=34
# http://wger.de/api/v2/exercise/?format=json&page=35

# %%
len(df_all_exercises)
# Out:
# 688

# %%
# Saving data to csv file                    
df_all_exercises.to_csv('exercises.csv',sep=',', encoding='utf-8', index=False)

# delete existing data in the table
cursor.execute("DELETE FROM exercise")
cursor.execute("DELETE FROM map_exercise_muscle")
db_connection.commit()

# Inserting each row
for row in df_all_exercises.iterrows():
    #print(row)
    description = row[1]['description']
    name = row[1]['name']
    name_original = row[1]['name_original']

    # Incase the 's is present in the string it adds an escape character i.e. ''
    if(description != ''):
        description = description.replace("'","''")
    if(name != ''):
        name = name.replace("'","''")
    if(name_original != ''):
        name_original = name_original.replace("'","''")
        
    query = """
    INSERT into exercise(id, status, description, name,
    name_original, creation_date, category, language) 
    values(%s,'%s','%s','%s','%s','%s',%s,%s);
    """ % (row[1]['id'], row[1]['status'], description, name,
          name_original, row[1]['creation_date'], row[1]['category'],
          row[1]['language'])

    cursor.execute(query)
    
    # Inserting data to map_exercise_muscle
    muscles = row[1]['muscles']
    if len(muscles) > 0:
        ex_id = row[1]['id']
        for m in muscles:
            #print(ex_id,m)
            ex_mu_query = """
            INSERT into map_exercise_muscle(ex_id, mu_id) 
            values(%s,%s);
            """ % (ex_id,m)
            cursor.execute(ex_mu_query)

    # Inserting data to map_exercise_equipment
    equipments = row[1]['equipment']
    if len(equipments) > 0:
        ex_id = row[1]['id']
        for e in equipments:
            ex_eq_query = """
            INSERT into map_exercise_equipment(ex_id, eq_id) 
            values(%s,%s);
            """ % (ex_id,e)
            cursor.execute(ex_eq_query)

# Close the connection - Saving the changes
db_connection.commit()
print("Data inserted successfully to exercise , map_exercise_muscle and map_exercise_equipment tables")
# Out:
# Data inserted successfully to exercise , map_exercise_muscle and map_exercise_equipment tables

# %% [markdown]
# ### Insert to - exerciseimage TABLE

# %%
url="http://wger.de/api/v2/exerciseimage/?format=json"
response = urlopen(url)
print(url)

# Extract the body of the reply
response_body = response.read()

# Decode the format in json format
exercise_images = json.loads(response_body.decode("utf-8"))

exercise_images_dict = exercise_images['next']

df_exercise_images = pd.DataFrame(exercise_images['results'])
        
list_df = []
list_df.append(df_exercise_images)
while exercise_images_dict != None:
    print(exercise_images_dict)
    response = urlopen(exercise_images_dict)
    response_body = response.read()
    exercise_images = json.loads(response_body.decode("utf-8"))
    list_df.append(pd.DataFrame(exercise_images['results']))
    exercise_images_dict = exercise_images['next']
df_all_exercise_images = pd.concat(list_df, axis=0, join='outer', ignore_index=False)
# Out:
# http://wger.de/api/v2/exerciseimage/?format=json
# http://wger.de/api/v2/exerciseimage/?format=json&page=2
# http://wger.de/api/v2/exerciseimage/?format=json&page=3
# http://wger.de/api/v2/exerciseimage/?format=json&page=4
# http://wger.de/api/v2/exerciseimage/?format=json&page=5
# http://wger.de/api/v2/exerciseimage/?format=json&page=6
# http://wger.de/api/v2/exerciseimage/?format=json&page=7
# http://wger.de/api/v2/exerciseimage/?format=json&page=8
# http://wger.de/api/v2/exerciseimage/?format=json&page=9
# http://wger.de/api/v2/exerciseimage/?format=json&page=10
# http://wger.de/api/v2/exerciseimage/?format=json&page=11

# %%
len(df_all_exercise_images)
# Out:
# 204

# %%
# Saving data to csv file                    
df_all_exercise_images.to_csv('exercise_images.csv',sep=',', encoding='utf-8', index=False)

# delete existing data in the table
cursor.execute("DELETE FROM exerciseimage")
db_connection.commit()

# Inserting each row
for row in df_all_exercise_images.iterrows():
        
    query = """
    INSERT into exerciseimage(id, status, image, is_main, exercise) 
    values(%s,'%s','%s',%s,%s);
    """ % (row[1]['id'], row[1]['status'], row[1]['image'],
           row[1]['is_main'], row[1]['exercise'])

    #print(query)
    cursor.execute(query)
    
# Close the connection - Saving the changes
db_connection.commit()
print("Data inserted successfully to exerciseimage tables")
# Out:
# Data inserted successfully to exerciseimage tables

# %% [markdown]
# ### Insert to - muscle TABLE

# %%
url="http://wger.de/api/v2/muscle/?format=json"
response = urlopen(url)

# Extract the body of the reply
response_body = response.read()

# Decode the format in json format
muscles = json.loads(response_body.decode("utf-8"))

df_muscles = pd.DataFrame(muscles['results'])

df_muscles.to_csv('muscles.csv',sep=',', encoding='utf-8', index=False)

# delete existing data in the table
cursor.execute("DELETE FROM muscle")
db_connection.commit()

# Now we will connect to the database and store muscles data
with open('muscles.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip the header row.
    for row in reader:
        cursor.execute( "INSERT INTO muscle VALUES (%s, %s, %s)", row)
db_connection.commit()
print("Data inserted successfully to muscle table")
# Out:
# Data inserted successfully to muscle table

# %% [markdown]
# ### Insert to - equipment TABLE

# %%
url="http://wger.de/api/v2/equipment/?format=json"
response = urlopen(url)

# Extract the body of the reply
response_body = response.read()

# Decode the format in json format
equipments = json.loads(response_body.decode("utf-8"))

df_equipments = pd.DataFrame(equipments['results'])

df_equipments.to_csv('equipments.csv',sep=',', encoding='utf-8', index=False)

# delete existing data in the table
cursor.execute("DELETE FROM equipment")
db_connection.commit()

# Now we will connect to the database and store equipments data
with open('equipments.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip the header row.
    for row in reader:
        cursor.execute( "INSERT INTO equipment VALUES (%s, %s)", row)
db_connection.commit()
print("Data inserted successfully to equipment table")
# Out:
# Data inserted successfully to equipment table

# %% [markdown]
# ### Insert to - ingredient TABLE

# %%
url="http://wger.de/api/v2/ingredient/?format=json"
response = urlopen(url)
print(url)

# Extract the body of the reply
response_body = response.read()

# Decode the format in json format
ingredients = json.loads(response_body.decode("utf-8"))

ingredients_dict = ingredients['next']

df_ingredients = pd.DataFrame(ingredients['results'])
        
list_df = []
list_df.append(df_ingredients)
while ingredients_dict != None:
    print(ingredients_dict)
    response = urlopen(ingredients_dict)
    response_body = response.read()
    ingredients = json.loads(response_body.decode("utf-8"))
    list_df.append(pd.DataFrame(ingredients['results']))
    ingredients_dict = ingredients['next']
df_all_ingredients = pd.concat(list_df, axis=0, join='outer', ignore_index=False)
# Out:
# http://wger.de/api/v2/ingredient/?format=json
# http://wger.de/api/v2/ingredient/?format=json&page=2
# http://wger.de/api/v2/ingredient/?format=json&page=3
# http://wger.de/api/v2/ingredient/?format=json&page=4
# http://wger.de/api/v2/ingredient/?format=json&page=5
# http://wger.de/api/v2/ingredient/?format=json&page=6
# http://wger.de/api/v2/ingredient/?format=json&page=7
# http://wger.de/api/v2/ingredient/?format=json&page=8
# http://wger.de/api/v2/ingredient/?format=json&page=9
# http://wger.de/api/v2/ingredient/?format=json&page=10
# http://wger.de/api/v2/ingredient/?format=json&page=11
# http://wger.de/api/v2/ingredient/?format=json&page=12
# http://wger.de/api/v2/ingredient/?format=json&page=13
# http://wger.de/api/v2/ingredient/?format=json&page=14
# http://wger.de/api/v2/ingredient/?format=json&page=15
# http://wger.de/api/v2/ingredient/?format=json&page=16
# http://wger.de/api/v2/ingredient/?format=json&page=17
# http://wger.de/api/v2/ingredient/?format=json&page=18
# http://wger.de/api/v2/ingredient/?format=json&page=19
# http://wger.de/api/v2/ingredient/?format=json&page=20
# http://wger.de/api/v2/ingredient/?format=json&page=21
# http://wger.de/api/v2/ingredient/?format=json&page=22
# http://wger.de/api/v2/ingredient/?format=json&page=23
# http://wger.de/api/v2/ingredient/?format=json&page=24
# http://wger.de/api/v2/ingredient/?format=json&page=25
# http://wger.de/api/v2/ingredient/?format=json&page=26
# http://wger.de/api/v2/ingredient/?format=json&page=27
# http://wger.de/api/v2/ingredient/?format=json&page=28
# http://wger.de/api/v2/ingredient/?format=json&page=29
# http://wger.de/api/v2/ingredient/?format=json&page=30
# http://wger.de/api/v2/ingredient/?format=json&page=31
# http://wger.de/api/v2/ingredient/?format=json&page=32
# http://wger.de/api/v2/ingredient/?format=json&page=33
# http://wger.de/api/v2/ingredient/?format=json&page=34
# http://wger.de/api/v2/ingredient/?format=json&page=35
# http://wger.de/api/v2/ingredient/?format=json&page=36
# http://wger.de/api/v2/ingredient/?format=json&page=37
# http://wger.de/api/v2/ingredient/?format=json&page=38
# http://wger.de/api/v2/ingredient/?format=json&page=39
# http://wger.de/api/v2/ingredient/?format=json&page=40
# http://wger.de/api/v2/ingredient/?format=json&page=41
# http://wger.de/api/v2/ingredient/?format=json&page=42
# http://wger.de/api/v2/ingredient/?format=json&page=43
# http://wger.de/api/v2/ingredient/?format=json&page=44
# http://wger.de/api/v2/ingredient/?format=json&page=45
# http://wger.de/api/v2/ingredient/?format=json&page=46
# http://wger.de/api/v2/ingredient/?format=json&page=47
# http://wger.de/api/v2/ingredient/?format=json&page=48
# http://wger.de/api/v2/ingredient/?format=json&page=49
# http://wger.de/api/v2/ingredient/?format=json&page=50
# http://wger.de/api/v2/ingredient/?format=json&page=51
# http://wger.de/api/v2/ingredient/?format=json&page=52
# http://wger.de/api/v2/ingredient/?format=json&page=53
# http://wger.de/api/v2/ingredient/?format=json&page=54
# http://wger.de/api/v2/ingredient/?format=json&page=55
# http://wger.de/api/v2/ingredient/?format=json&page=56
# http://wger.de/api/v2/ingredient/?format=json&page=57
# http://wger.de/api/v2/ingredient/?format=json&page=58
# http://wger.de/api/v2/ingredient/?format=json&page=59
# http://wger.de/api/v2/ingredient/?format=json&page=60
# http://wger.de/api/v2/ingredient/?format=json&page=61
# http://wger.de/api/v2/ingredient/?format=json&page=62
# http://wger.de/api/v2/ingredient/?format=json&page=63
# http://wger.de/api/v2/ingredient/?format=json&page=64
# http://wger.de/api/v2/ingredient/?format=json&page=65
# http://wger.de/api/v2/ingredient/?format=json&page=66
# http://wger.de/api/v2/ingredient/?format=json&page=67
# http://wger.de/api/v2/ingredient/?format=json&page=68
# http://wger.de/api/v2/ingredient/?format=json&page=69
# http://wger.de/api/v2/ingredient/?format=json&page=70
# http://wger.de/api/v2/ingredient/?format=json&page=71
# http://wger.de/api/v2/ingredient/?format=json&page=72
# http://wger.de/api/v2/ingredient/?format=json&page=73
# http://wger.de/api/v2/ingredient/?format=json&page=74
# http://wger.de/api/v2/ingredient/?format=json&page=75
# http://wger.de/api/v2/ingredient/?format=json&page=76
# http://wger.de/api/v2/ingredient/?format=json&page=77
# http://wger.de/api/v2/ingredient/?format=json&page=78
# http://wger.de/api/v2/ingredient/?format=json&page=79
# http://wger.de/api/v2/ingredient/?format=json&page=80
# http://wger.de/api/v2/ingredient/?format=json&page=81
# http://wger.de/api/v2/ingredient/?format=json&page=82
# http://wger.de/api/v2/ingredient/?format=json&page=83
# http://wger.de/api/v2/ingredient/?format=json&page=84
# http://wger.de/api/v2/ingredient/?format=json&page=85
# http://wger.de/api/v2/ingredient/?format=json&page=86
# http://wger.de/api/v2/ingredient/?format=json&page=87
# http://wger.de/api/v2/ingredient/?format=json&page=88
# http://wger.de/api/v2/ingredient/?format=json&page=89
# http://wger.de/api/v2/ingredient/?format=json&page=90
# http://wger.de/api/v2/ingredient/?format=json&page=91
# http://wger.de/api/v2/ingredient/?format=json&page=92
# http://wger.de/api/v2/ingredient/?format=json&page=93
# http://wger.de/api/v2/ingredient/?format=json&page=94
# http://wger.de/api/v2/ingredient/?format=json&page=95
# http://wger.de/api/v2/ingredient/?format=json&page=96
# http://wger.de/api/v2/ingredient/?format=json&page=97
# http://wger.de/api/v2/ingredient/?format=json&page=98
# http://wger.de/api/v2/ingredient/?format=json&page=99
# http://wger.de/api/v2/ingredient/?format=json&page=100
# http://wger.de/api/v2/ingredient/?format=json&page=101
# http://wger.de/api/v2/ingredient/?format=json&page=102
# http://wger.de/api/v2/ingredient/?format=json&page=103
# http://wger.de/api/v2/ingredient/?format=json&page=104
# http://wger.de/api/v2/ingredient/?format=json&page=105
# http://wger.de/api/v2/ingredient/?format=json&page=106
# http://wger.de/api/v2/ingredient/?format=json&page=107
# http://wger.de/api/v2/ingredient/?format=json&page=108
# http://wger.de/api/v2/ingredient/?format=json&page=109
# http://wger.de/api/v2/ingredient/?format=json&page=110
# http://wger.de/api/v2/ingredient/?format=json&page=111
# http://wger.de/api/v2/ingredient/?format=json&page=112
# http://wger.de/api/v2/ingredient/?format=json&page=113
# http://wger.de/api/v2/ingredient/?format=json&page=114
# http://wger.de/api/v2/ingredient/?format=json&page=115
# http://wger.de/api/v2/ingredient/?format=json&page=116
# http://wger.de/api/v2/ingredient/?format=json&page=117
# http://wger.de/api/v2/ingredient/?format=json&page=118
# http://wger.de/api/v2/ingredient/?format=json&page=119
# http://wger.de/api/v2/ingredient/?format=json&page=120
# http://wger.de/api/v2/ingredient/?format=json&page=121
# http://wger.de/api/v2/ingredient/?format=json&page=122
# http://wger.de/api/v2/ingredient/?format=json&page=123
# http://wger.de/api/v2/ingredient/?format=json&page=124
# http://wger.de/api/v2/ingredient/?format=json&page=125
# http://wger.de/api/v2/ingredient/?format=json&page=126
# http://wger.de/api/v2/ingredient/?format=json&page=127
# http://wger.de/api/v2/ingredient/?format=json&page=128
# http://wger.de/api/v2/ingredient/?format=json&page=129
# http://wger.de/api/v2/ingredient/?format=json&page=130
# http://wger.de/api/v2/ingredient/?format=json&page=131
# http://wger.de/api/v2/ingredient/?format=json&page=132
# http://wger.de/api/v2/ingredient/?format=json&page=133
# http://wger.de/api/v2/ingredient/?format=json&page=134
# http://wger.de/api/v2/ingredient/?format=json&page=135
# http://wger.de/api/v2/ingredient/?format=json&page=136
# http://wger.de/api/v2/ingredient/?format=json&page=137
# http://wger.de/api/v2/ingredient/?format=json&page=138
# http://wger.de/api/v2/ingredient/?format=json&page=139
# http://wger.de/api/v2/ingredient/?format=json&page=140
# http://wger.de/api/v2/ingredient/?format=json&page=141
# http://wger.de/api/v2/ingredient/?format=json&page=142
# http://wger.de/api/v2/ingredient/?format=json&page=143
# http://wger.de/api/v2/ingredient/?format=json&page=144
# http://wger.de/api/v2/ingredient/?format=json&page=145
# http://wger.de/api/v2/ingredient/?format=json&page=146
# http://wger.de/api/v2/ingredient/?format=json&page=147
# http://wger.de/api/v2/ingredient/?format=json&page=148
# http://wger.de/api/v2/ingredient/?format=json&page=149
# http://wger.de/api/v2/ingredient/?format=json&page=150
# http://wger.de/api/v2/ingredient/?format=json&page=151
# http://wger.de/api/v2/ingredient/?format=json&page=152
# http://wger.de/api/v2/ingredient/?format=json&page=153
# http://wger.de/api/v2/ingredient/?format=json&page=154
# http://wger.de/api/v2/ingredient/?format=json&page=155
# http://wger.de/api/v2/ingredient/?format=json&page=156
# http://wger.de/api/v2/ingredient/?format=json&page=157
# http://wger.de/api/v2/ingredient/?format=json&page=158
# http://wger.de/api/v2/ingredient/?format=json&page=159
# http://wger.de/api/v2/ingredient/?format=json&page=160
# http://wger.de/api/v2/ingredient/?format=json&page=161
# http://wger.de/api/v2/ingredient/?format=json&page=162
# http://wger.de/api/v2/ingredient/?format=json&page=163
# http://wger.de/api/v2/ingredient/?format=json&page=164
# http://wger.de/api/v2/ingredient/?format=json&page=165
# http://wger.de/api/v2/ingredient/?format=json&page=166
# http://wger.de/api/v2/ingredient/?format=json&page=167
# http://wger.de/api/v2/ingredient/?format=json&page=168
# http://wger.de/api/v2/ingredient/?format=json&page=169
# http://wger.de/api/v2/ingredient/?format=json&page=170
# http://wger.de/api/v2/ingredient/?format=json&page=171
# http://wger.de/api/v2/ingredient/?format=json&page=172
# http://wger.de/api/v2/ingredient/?format=json&page=173
# http://wger.de/api/v2/ingredient/?format=json&page=174
# http://wger.de/api/v2/ingredient/?format=json&page=175
# http://wger.de/api/v2/ingredient/?format=json&page=176
# http://wger.de/api/v2/ingredient/?format=json&page=177
# http://wger.de/api/v2/ingredient/?format=json&page=178
# http://wger.de/api/v2/ingredient/?format=json&page=179
# http://wger.de/api/v2/ingredient/?format=json&page=180
# http://wger.de/api/v2/ingredient/?format=json&page=181
# http://wger.de/api/v2/ingredient/?format=json&page=182
# http://wger.de/api/v2/ingredient/?format=json&page=183
# http://wger.de/api/v2/ingredient/?format=json&page=184
# http://wger.de/api/v2/ingredient/?format=json&page=185
# http://wger.de/api/v2/ingredient/?format=json&page=186
# http://wger.de/api/v2/ingredient/?format=json&page=187
# http://wger.de/api/v2/ingredient/?format=json&page=188
# http://wger.de/api/v2/ingredient/?format=json&page=189
# http://wger.de/api/v2/ingredient/?format=json&page=190
# http://wger.de/api/v2/ingredient/?format=json&page=191
# http://wger.de/api/v2/ingredient/?format=json&page=192
# http://wger.de/api/v2/ingredient/?format=json&page=193
# http://wger.de/api/v2/ingredient/?format=json&page=194
# http://wger.de/api/v2/ingredient/?format=json&page=195
# http://wger.de/api/v2/ingredient/?format=json&page=196
# http://wger.de/api/v2/ingredient/?format=json&page=197
# http://wger.de/api/v2/ingredient/?format=json&page=198
# http://wger.de/api/v2/ingredient/?format=json&page=199
# http://wger.de/api/v2/ingredient/?format=json&page=200
# http://wger.de/api/v2/ingredient/?format=json&page=201
# http://wger.de/api/v2/ingredient/?format=json&page=202
# http://wger.de/api/v2/ingredient/?format=json&page=203
# http://wger.de/api/v2/ingredient/?format=json&page=204
# http://wger.de/api/v2/ingredient/?format=json&page=205
# http://wger.de/api/v2/ingredient/?format=json&page=206
# http://wger.de/api/v2/ingredient/?format=json&page=207
# http://wger.de/api/v2/ingredient/?format=json&page=208
# http://wger.de/api/v2/ingredient/?format=json&page=209
# http://wger.de/api/v2/ingredient/?format=json&page=210
# http://wger.de/api/v2/ingredient/?format=json&page=211
# http://wger.de/api/v2/ingredient/?format=json&page=212
# http://wger.de/api/v2/ingredient/?format=json&page=213
# http://wger.de/api/v2/ingredient/?format=json&page=214
# http://wger.de/api/v2/ingredient/?format=json&page=215
# http://wger.de/api/v2/ingredient/?format=json&page=216
# http://wger.de/api/v2/ingredient/?format=json&page=217
# http://wger.de/api/v2/ingredient/?format=json&page=218
# http://wger.de/api/v2/ingredient/?format=json&page=219
# http://wger.de/api/v2/ingredient/?format=json&page=220
# http://wger.de/api/v2/ingredient/?format=json&page=221
# http://wger.de/api/v2/ingredient/?format=json&page=222
# http://wger.de/api/v2/ingredient/?format=json&page=223
# http://wger.de/api/v2/ingredient/?format=json&page=224
# http://wger.de/api/v2/ingredient/?format=json&page=225
# http://wger.de/api/v2/ingredient/?format=json&page=226
# http://wger.de/api/v2/ingredient/?format=json&page=227
# http://wger.de/api/v2/ingredient/?format=json&page=228
# http://wger.de/api/v2/ingredient/?format=json&page=229
# http://wger.de/api/v2/ingredient/?format=json&page=230
# http://wger.de/api/v2/ingredient/?format=json&page=231
# http://wger.de/api/v2/ingredient/?format=json&page=232
# http://wger.de/api/v2/ingredient/?format=json&page=233
# http://wger.de/api/v2/ingredient/?format=json&page=234
# http://wger.de/api/v2/ingredient/?format=json&page=235
# http://wger.de/api/v2/ingredient/?format=json&page=236
# http://wger.de/api/v2/ingredient/?format=json&page=237
# http://wger.de/api/v2/ingredient/?format=json&page=238
# http://wger.de/api/v2/ingredient/?format=json&page=239
# http://wger.de/api/v2/ingredient/?format=json&page=240
# http://wger.de/api/v2/ingredient/?format=json&page=241
# http://wger.de/api/v2/ingredient/?format=json&page=242
# http://wger.de/api/v2/ingredient/?format=json&page=243
# http://wger.de/api/v2/ingredient/?format=json&page=244
# http://wger.de/api/v2/ingredient/?format=json&page=245
# http://wger.de/api/v2/ingredient/?format=json&page=246
# http://wger.de/api/v2/ingredient/?format=json&page=247
# http://wger.de/api/v2/ingredient/?format=json&page=248
# http://wger.de/api/v2/ingredient/?format=json&page=249
# http://wger.de/api/v2/ingredient/?format=json&page=250
# http://wger.de/api/v2/ingredient/?format=json&page=251
# http://wger.de/api/v2/ingredient/?format=json&page=252
# http://wger.de/api/v2/ingredient/?format=json&page=253
# http://wger.de/api/v2/ingredient/?format=json&page=254
# http://wger.de/api/v2/ingredient/?format=json&page=255
# http://wger.de/api/v2/ingredient/?format=json&page=256
# http://wger.de/api/v2/ingredient/?format=json&page=257
# http://wger.de/api/v2/ingredient/?format=json&page=258
# http://wger.de/api/v2/ingredient/?format=json&page=259
# http://wger.de/api/v2/ingredient/?format=json&page=260
# http://wger.de/api/v2/ingredient/?format=json&page=261
# http://wger.de/api/v2/ingredient/?format=json&page=262
# http://wger.de/api/v2/ingredient/?format=json&page=263
# http://wger.de/api/v2/ingredient/?format=json&page=264
# http://wger.de/api/v2/ingredient/?format=json&page=265
# http://wger.de/api/v2/ingredient/?format=json&page=266
# http://wger.de/api/v2/ingredient/?format=json&page=267
# http://wger.de/api/v2/ingredient/?format=json&page=268
# http://wger.de/api/v2/ingredient/?format=json&page=269
# http://wger.de/api/v2/ingredient/?format=json&page=270
# http://wger.de/api/v2/ingredient/?format=json&page=271
# http://wger.de/api/v2/ingredient/?format=json&page=272
# http://wger.de/api/v2/ingredient/?format=json&page=273
# http://wger.de/api/v2/ingredient/?format=json&page=274
# http://wger.de/api/v2/ingredient/?format=json&page=275
# http://wger.de/api/v2/ingredient/?format=json&page=276
# http://wger.de/api/v2/ingredient/?format=json&page=277
# http://wger.de/api/v2/ingredient/?format=json&page=278
# http://wger.de/api/v2/ingredient/?format=json&page=279
# http://wger.de/api/v2/ingredient/?format=json&page=280
# http://wger.de/api/v2/ingredient/?format=json&page=281
# http://wger.de/api/v2/ingredient/?format=json&page=282
# http://wger.de/api/v2/ingredient/?format=json&page=283
# http://wger.de/api/v2/ingredient/?format=json&page=284
# http://wger.de/api/v2/ingredient/?format=json&page=285
# http://wger.de/api/v2/ingredient/?format=json&page=286
# http://wger.de/api/v2/ingredient/?format=json&page=287
# http://wger.de/api/v2/ingredient/?format=json&page=288
# http://wger.de/api/v2/ingredient/?format=json&page=289
# http://wger.de/api/v2/ingredient/?format=json&page=290
# http://wger.de/api/v2/ingredient/?format=json&page=291
# http://wger.de/api/v2/ingredient/?format=json&page=292
# http://wger.de/api/v2/ingredient/?format=json&page=293
# http://wger.de/api/v2/ingredient/?format=json&page=294
# http://wger.de/api/v2/ingredient/?format=json&page=295
# http://wger.de/api/v2/ingredient/?format=json&page=296
# http://wger.de/api/v2/ingredient/?format=json&page=297
# http://wger.de/api/v2/ingredient/?format=json&page=298
# http://wger.de/api/v2/ingredient/?format=json&page=299
# http://wger.de/api/v2/ingredient/?format=json&page=300
# http://wger.de/api/v2/ingredient/?format=json&page=301
# http://wger.de/api/v2/ingredient/?format=json&page=302
# http://wger.de/api/v2/ingredient/?format=json&page=303
# http://wger.de/api/v2/ingredient/?format=json&page=304
# http://wger.de/api/v2/ingredient/?format=json&page=305
# http://wger.de/api/v2/ingredient/?format=json&page=306
# http://wger.de/api/v2/ingredient/?format=json&page=307
# http://wger.de/api/v2/ingredient/?format=json&page=308
# http://wger.de/api/v2/ingredient/?format=json&page=309
# http://wger.de/api/v2/ingredient/?format=json&page=310
# http://wger.de/api/v2/ingredient/?format=json&page=311
# http://wger.de/api/v2/ingredient/?format=json&page=312
# http://wger.de/api/v2/ingredient/?format=json&page=313
# http://wger.de/api/v2/ingredient/?format=json&page=314
# http://wger.de/api/v2/ingredient/?format=json&page=315
# http://wger.de/api/v2/ingredient/?format=json&page=316
# http://wger.de/api/v2/ingredient/?format=json&page=317
# http://wger.de/api/v2/ingredient/?format=json&page=318
# http://wger.de/api/v2/ingredient/?format=json&page=319
# http://wger.de/api/v2/ingredient/?format=json&page=320
# http://wger.de/api/v2/ingredient/?format=json&page=321
# http://wger.de/api/v2/ingredient/?format=json&page=322
# http://wger.de/api/v2/ingredient/?format=json&page=323
# http://wger.de/api/v2/ingredient/?format=json&page=324
# http://wger.de/api/v2/ingredient/?format=json&page=325
# http://wger.de/api/v2/ingredient/?format=json&page=326
# http://wger.de/api/v2/ingredient/?format=json&page=327
# http://wger.de/api/v2/ingredient/?format=json&page=328
# http://wger.de/api/v2/ingredient/?format=json&page=329
# http://wger.de/api/v2/ingredient/?format=json&page=330
# http://wger.de/api/v2/ingredient/?format=json&page=331
# http://wger.de/api/v2/ingredient/?format=json&page=332
# http://wger.de/api/v2/ingredient/?format=json&page=333
# http://wger.de/api/v2/ingredient/?format=json&page=334
# http://wger.de/api/v2/ingredient/?format=json&page=335
# http://wger.de/api/v2/ingredient/?format=json&page=336
# http://wger.de/api/v2/ingredient/?format=json&page=337
# http://wger.de/api/v2/ingredient/?format=json&page=338
# http://wger.de/api/v2/ingredient/?format=json&page=339
# http://wger.de/api/v2/ingredient/?format=json&page=340
# http://wger.de/api/v2/ingredient/?format=json&page=341
# http://wger.de/api/v2/ingredient/?format=json&page=342
# http://wger.de/api/v2/ingredient/?format=json&page=343
# http://wger.de/api/v2/ingredient/?format=json&page=344
# http://wger.de/api/v2/ingredient/?format=json&page=345
# http://wger.de/api/v2/ingredient/?format=json&page=346
# http://wger.de/api/v2/ingredient/?format=json&page=347
# http://wger.de/api/v2/ingredient/?format=json&page=348
# http://wger.de/api/v2/ingredient/?format=json&page=349
# http://wger.de/api/v2/ingredient/?format=json&page=350
# http://wger.de/api/v2/ingredient/?format=json&page=351
# http://wger.de/api/v2/ingredient/?format=json&page=352
# http://wger.de/api/v2/ingredient/?format=json&page=353
# http://wger.de/api/v2/ingredient/?format=json&page=354
# http://wger.de/api/v2/ingredient/?format=json&page=355
# http://wger.de/api/v2/ingredient/?format=json&page=356
# http://wger.de/api/v2/ingredient/?format=json&page=357
# http://wger.de/api/v2/ingredient/?format=json&page=358
# http://wger.de/api/v2/ingredient/?format=json&page=359
# http://wger.de/api/v2/ingredient/?format=json&page=360
# http://wger.de/api/v2/ingredient/?format=json&page=361
# http://wger.de/api/v2/ingredient/?format=json&page=362
# http://wger.de/api/v2/ingredient/?format=json&page=363
# http://wger.de/api/v2/ingredient/?format=json&page=364
# http://wger.de/api/v2/ingredient/?format=json&page=365
# http://wger.de/api/v2/ingredient/?format=json&page=366
# http://wger.de/api/v2/ingredient/?format=json&page=367
# http://wger.de/api/v2/ingredient/?format=json&page=368
# http://wger.de/api/v2/ingredient/?format=json&page=369
# http://wger.de/api/v2/ingredient/?format=json&page=370
# http://wger.de/api/v2/ingredient/?format=json&page=371
# http://wger.de/api/v2/ingredient/?format=json&page=372
# http://wger.de/api/v2/ingredient/?format=json&page=373
# http://wger.de/api/v2/ingredient/?format=json&page=374
# http://wger.de/api/v2/ingredient/?format=json&page=375
# http://wger.de/api/v2/ingredient/?format=json&page=376
# http://wger.de/api/v2/ingredient/?format=json&page=377
# http://wger.de/api/v2/ingredient/?format=json&page=378
# http://wger.de/api/v2/ingredient/?format=json&page=379
# http://wger.de/api/v2/ingredient/?format=json&page=380
# http://wger.de/api/v2/ingredient/?format=json&page=381
# http://wger.de/api/v2/ingredient/?format=json&page=382
# http://wger.de/api/v2/ingredient/?format=json&page=383
# http://wger.de/api/v2/ingredient/?format=json&page=384
# http://wger.de/api/v2/ingredient/?format=json&page=385
# http://wger.de/api/v2/ingredient/?format=json&page=386
# http://wger.de/api/v2/ingredient/?format=json&page=387
# http://wger.de/api/v2/ingredient/?format=json&page=388
# http://wger.de/api/v2/ingredient/?format=json&page=389
# http://wger.de/api/v2/ingredient/?format=json&page=390
# http://wger.de/api/v2/ingredient/?format=json&page=391
# http://wger.de/api/v2/ingredient/?format=json&page=392
# http://wger.de/api/v2/ingredient/?format=json&page=393
# http://wger.de/api/v2/ingredient/?format=json&page=394
# http://wger.de/api/v2/ingredient/?format=json&page=395
# http://wger.de/api/v2/ingredient/?format=json&page=396
# http://wger.de/api/v2/ingredient/?format=json&page=397
# http://wger.de/api/v2/ingredient/?format=json&page=398
# http://wger.de/api/v2/ingredient/?format=json&page=399
# http://wger.de/api/v2/ingredient/?format=json&page=400
# http://wger.de/api/v2/ingredient/?format=json&page=401
# http://wger.de/api/v2/ingredient/?format=json&page=402
# http://wger.de/api/v2/ingredient/?format=json&page=403
# http://wger.de/api/v2/ingredient/?format=json&page=404
# http://wger.de/api/v2/ingredient/?format=json&page=405
# http://wger.de/api/v2/ingredient/?format=json&page=406
# http://wger.de/api/v2/ingredient/?format=json&page=407
# http://wger.de/api/v2/ingredient/?format=json&page=408
# http://wger.de/api/v2/ingredient/?format=json&page=409
# http://wger.de/api/v2/ingredient/?format=json&page=410
# http://wger.de/api/v2/ingredient/?format=json&page=411
# http://wger.de/api/v2/ingredient/?format=json&page=412
# http://wger.de/api/v2/ingredient/?format=json&page=413
# http://wger.de/api/v2/ingredient/?format=json&page=414
# http://wger.de/api/v2/ingredient/?format=json&page=415
# http://wger.de/api/v2/ingredient/?format=json&page=416
# http://wger.de/api/v2/ingredient/?format=json&page=417
# http://wger.de/api/v2/ingredient/?format=json&page=418
# http://wger.de/api/v2/ingredient/?format=json&page=419
# http://wger.de/api/v2/ingredient/?format=json&page=420
# http://wger.de/api/v2/ingredient/?format=json&page=421
# http://wger.de/api/v2/ingredient/?format=json&page=422
# http://wger.de/api/v2/ingredient/?format=json&page=423
# http://wger.de/api/v2/ingredient/?format=json&page=424
# http://wger.de/api/v2/ingredient/?format=json&page=425
# http://wger.de/api/v2/ingredient/?format=json&page=426
# http://wger.de/api/v2/ingredient/?format=json&page=427
# http://wger.de/api/v2/ingredient/?format=json&page=428
# http://wger.de/api/v2/ingredient/?format=json&page=429
# http://wger.de/api/v2/ingredient/?format=json&page=430
# http://wger.de/api/v2/ingredient/?format=json&page=431
# http://wger.de/api/v2/ingredient/?format=json&page=432
# http://wger.de/api/v2/ingredient/?format=json&page=433
# http://wger.de/api/v2/ingredient/?format=json&page=434
# http://wger.de/api/v2/ingredient/?format=json&page=435
# http://wger.de/api/v2/ingredient/?format=json&page=436
# http://wger.de/api/v2/ingredient/?format=json&page=437
# http://wger.de/api/v2/ingredient/?format=json&page=438
# http://wger.de/api/v2/ingredient/?format=json&page=439
# http://wger.de/api/v2/ingredient/?format=json&page=440
# http://wger.de/api/v2/ingredient/?format=json&page=441
# http://wger.de/api/v2/ingredient/?format=json&page=442
# http://wger.de/api/v2/ingredient/?format=json&page=443
# http://wger.de/api/v2/ingredient/?format=json&page=444
# http://wger.de/api/v2/ingredient/?format=json&page=445
# http://wger.de/api/v2/ingredient/?format=json&page=446
# http://wger.de/api/v2/ingredient/?format=json&page=447
# http://wger.de/api/v2/ingredient/?format=json&page=448
# http://wger.de/api/v2/ingredient/?format=json&page=449
# http://wger.de/api/v2/ingredient/?format=json&page=450
# http://wger.de/api/v2/ingredient/?format=json&page=451
# http://wger.de/api/v2/ingredient/?format=json&page=452
# http://wger.de/api/v2/ingredient/?format=json&page=453
# http://wger.de/api/v2/ingredient/?format=json&page=454
# http://wger.de/api/v2/ingredient/?format=json&page=455
# http://wger.de/api/v2/ingredient/?format=json&page=456
# http://wger.de/api/v2/ingredient/?format=json&page=457
# http://wger.de/api/v2/ingredient/?format=json&page=458
# http://wger.de/api/v2/ingredient/?format=json&page=459
# http://wger.de/api/v2/ingredient/?format=json&page=460
# http://wger.de/api/v2/ingredient/?format=json&page=461
# http://wger.de/api/v2/ingredient/?format=json&page=462

# %%
print(len(df_all_ingredients))
df_all_ingredients.fillna('')
df_all_ingredients_new = df_all_ingredients
df_all_ingredients_new
df_all_ingredients_new.replace(r'^\s*$', np.nan, regex=True)
df_all_ingredients_new.fillna('')
# Out:
# 9226
#       id     license_author status creation_date update_date  \
# 0   9217           quintern      1    2017-02-26  2017-02-26
# 1   9218           quintern      1    2017-02-26  2017-02-26
# 2   8304            wger.de      2    2013-04-14  2017-01-19
# 3   8336  alphafitness.club      2    2017-01-19  2017-01-19
# 4   8337  alphafitness.club      2    2017-01-19  2017-01-19
# ..   ...                ...    ...           ...         ...
# 1   9213  alphafitness.club      2    2017-01-19  2017-01-19
# 2   9214  alphafitness.club      2    2017-01-19  2017-01-19
# 3    433            wger.de      2    2013-04-14  2017-01-19
# 4   8292            wger.de      2    2013-04-14  2017-01-19
# 5   9215  alphafitness.club      2    2017-01-19  2017-01-19
#
#                                                  name  energy protein  \
# 0                     365 Organic Green Lentils - Raw     360  26.000
# 1   365 Organic Super Grains - a blend of white an...     360  12.000
# 2                                      4-Korn Waffeln     403  10.200
# 3                                           Aalbessen      24   1.000
# 4                                         Aardappelen      85   2.600
# ..                                                ...     ...     ...
# 1                                             Zuurtje     380   0.000
# 2                                       Zwarte bessen      40   2.000
# 3                                            Zwieback     426  10.100
# 4                                       Zwiebeln, roh      40   1.100
# 5                                Zwitserse strooikaas     128  32.000
#
#    carbohydrates carbohydrates_sugar    fat fat_saturated fibres sodium  \
# 0         60.000               2.000  1.000         0.000         0.000
# 1         66.000               0.000  5.000         0.000         0.000
# 2         80.200                      3.900
# 3          5.000                      0.000
# 4         18.600                      0.000
# ..           ...                 ...    ...           ...    ...    ...
# 1         95.000                      0.000
# 2          8.000                      0.000
# 3         74.200              12.500  9.700         2.525  2.500  0.227
# 4          9.340               4.240  0.100         0.042  1.700  0.004
# 5          0.000                      0.000
#
#     license  language
# 0         2         2
# 1         2         2
# 2         1         1
# 3         2         6
# 4         2         6
# ..      ...       ...
# 1         2         6
# 2         2         6
# 3         1         2
# 4         1         1
# 5         2         6
#
# [9226 rows x 16 columns]

# %%
# Saving data to csv file                    
df_all_ingredients_new.to_csv('ingredients.csv',sep=',', encoding='utf-8', index=False)

# delete existing data in the table
cursor.execute("DELETE FROM ingredient")
db_connection.commit()

# Inserting each row
for row in df_all_ingredients_new.iterrows():
    fiber = row[1]['fibres']
    if fiber == None :
        fiber = ''
    if(name != ''):
        name = name.replace("'","''")
        
    query = """
    INSERT into ingredient(id, status, name, energy,
    protein, carbohydrates,carbohydrates_sugar, fat,
    fat_saturated, fibres, sodium,language) 
    values(%s,'%s','%s',%s,'%s','%s','%s','%s','%s','%s','%s',%s);
    """ % (row[1]['id'], row[1]['status'], name,row[1]['energy'],
           row[1]['protein'], row[1]['carbohydrates'], row[1]['carbohydrates_sugar'],row[1]['fat'],
           row[1]['fat_saturated'], fiber,row[1]['sodium'],row[1]['language'] )

    #print(query)
    cursor.execute(query)
    
# Close the connection - Saving the changes
db_connection.commit()
print("Data inserted successfully to ingredient table")
# Out:
# Data inserted successfully to ingredient table

# %% [markdown]
# ### Insert into - ingredientweightunit TABLE

# %%
url="http://wger.de/api/v2/ingredientweightunit/?format=json"
response = urlopen(url)
print(url)

# Extract the body of the reply
response_body = response.read()

# Decode the format in json format
ingredientsweight = json.loads(response_body.decode("utf-8"))

ingredientsweight_dict = ingredientsweight['next']

df_ingredientsweight = pd.DataFrame(ingredientsweight['results'])
        
list_df = []
list_df.append(df_ingredientsweight)
while ingredientsweight_dict != None:
    print(ingredientsweight_dict)
    response = urlopen(ingredientsweight_dict)
    response_body = response.read()
    ingredientsweight = json.loads(response_body.decode("utf-8"))
    list_df.append(pd.DataFrame(ingredientsweight['results']))
    ingredientsweight_dict = ingredientsweight['next']
df_all_ingredientsweight = pd.concat(list_df, axis=0, join='outer', ignore_index=False)
# Out:
# http://wger.de/api/v2/ingredientweightunit/?format=json
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=2
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=3
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=4
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=5
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=6
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=7
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=8
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=9
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=10
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=11
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=12
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=13
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=14
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=15
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=16
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=17
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=18
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=19
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=20
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=21
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=22
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=23
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=24
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=25
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=26
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=27
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=28
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=29
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=30
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=31
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=32
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=33
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=34
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=35
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=36
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=37
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=38
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=39
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=40
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=41
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=42
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=43
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=44
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=45
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=46
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=47
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=48
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=49
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=50
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=51
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=52
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=53
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=54
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=55
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=56
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=57
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=58
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=59
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=60
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=61
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=62
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=63
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=64
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=65
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=66
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=67
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=68
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=69
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=70
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=71
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=72
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=73
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=74
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=75
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=76
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=77
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=78
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=79
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=80
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=81
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=82
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=83
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=84
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=85
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=86
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=87
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=88
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=89
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=90
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=91
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=92
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=93
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=94
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=95
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=96
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=97
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=98
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=99
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=100
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=101
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=102
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=103
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=104
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=105
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=106
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=107
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=108
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=109
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=110
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=111
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=112
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=113
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=114
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=115
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=116
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=117
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=118
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=119
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=120
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=121
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=122
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=123
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=124
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=125
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=126
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=127
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=128
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=129
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=130
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=131
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=132
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=133
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=134
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=135
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=136
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=137
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=138
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=139
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=140
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=141
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=142
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=143
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=144
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=145
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=146
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=147
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=148
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=149
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=150
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=151
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=152
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=153
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=154
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=155
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=156
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=157
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=158
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=159
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=160
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=161
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=162
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=163
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=164
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=165
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=166
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=167
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=168
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=169
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=170
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=171
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=172
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=173
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=174
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=175
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=176
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=177
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=178
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=179
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=180
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=181
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=182
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=183
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=184
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=185
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=186
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=187
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=188
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=189
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=190
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=191
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=192
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=193
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=194
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=195
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=196
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=197
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=198
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=199
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=200
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=201
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=202
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=203
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=204
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=205
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=206
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=207
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=208
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=209
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=210
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=211
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=212
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=213
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=214
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=215
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=216
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=217
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=218
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=219
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=220
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=221
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=222
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=223
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=224
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=225
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=226
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=227
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=228
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=229
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=230
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=231
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=232
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=233
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=234
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=235
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=236
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=237
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=238
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=239
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=240
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=241
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=242
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=243
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=244
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=245
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=246
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=247
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=248
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=249
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=250
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=251
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=252
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=253
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=254
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=255
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=256
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=257
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=258
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=259
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=260
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=261
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=262
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=263
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=264
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=265
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=266
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=267
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=268
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=269
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=270
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=271
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=272
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=273
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=274
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=275
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=276
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=277
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=278
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=279
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=280
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=281
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=282
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=283
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=284
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=285
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=286
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=287
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=288
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=289
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=290
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=291
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=292
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=293
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=294
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=295
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=296
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=297
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=298
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=299
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=300
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=301
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=302
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=303
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=304
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=305
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=306
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=307
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=308
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=309
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=310
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=311
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=312
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=313
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=314
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=315
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=316
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=317
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=318
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=319
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=320
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=321
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=322
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=323
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=324
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=325
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=326
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=327
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=328
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=329
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=330
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=331
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=332
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=333
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=334
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=335
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=336
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=337
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=338
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=339
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=340
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=341
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=342
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=343
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=344
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=345
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=346
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=347
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=348
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=349
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=350
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=351
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=352
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=353
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=354
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=355
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=356
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=357
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=358
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=359
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=360
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=361
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=362
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=363
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=364
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=365
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=366
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=367
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=368
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=369
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=370
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=371
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=372
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=373
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=374
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=375
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=376
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=377
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=378
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=379
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=380
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=381
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=382
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=383
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=384
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=385
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=386
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=387
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=388
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=389
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=390
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=391
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=392
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=393
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=394
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=395
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=396
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=397
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=398
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=399
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=400
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=401
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=402
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=403
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=404
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=405
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=406
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=407
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=408
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=409
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=410
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=411
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=412
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=413
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=414
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=415
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=416
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=417
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=418
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=419
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=420
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=421
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=422
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=423
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=424
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=425
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=426
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=427
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=428
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=429
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=430
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=431
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=432
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=433
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=434
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=435
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=436
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=437
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=438
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=439
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=440
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=441
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=442
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=443
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=444
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=445
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=446
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=447
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=448
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=449
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=450
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=451
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=452
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=453
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=454
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=455
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=456
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=457
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=458
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=459
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=460
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=461
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=462
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=463
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=464
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=465
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=466
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=467
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=468
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=469
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=470
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=471
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=472
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=473
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=474
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=475
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=476
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=477
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=478
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=479
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=480
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=481
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=482
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=483
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=484
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=485
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=486
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=487
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=488
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=489
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=490
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=491
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=492
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=493
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=494
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=495
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=496
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=497
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=498
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=499
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=500
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=501
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=502
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=503
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=504
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=505
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=506
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=507
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=508
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=509
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=510
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=511
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=512
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=513
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=514
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=515
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=516
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=517
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=518
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=519
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=520
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=521
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=522
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=523
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=524
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=525
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=526
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=527
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=528
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=529
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=530
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=531
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=532
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=533
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=534
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=535
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=536
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=537
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=538
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=539
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=540
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=541
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=542
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=543
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=544
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=545
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=546
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=547
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=548
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=549
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=550
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=551
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=552
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=553
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=554
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=555
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=556
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=557
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=558
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=559
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=560
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=561
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=562
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=563
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=564
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=565
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=566
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=567
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=568
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=569
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=570
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=571
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=572
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=573
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=574
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=575
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=576
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=577
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=578
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=579
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=580
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=581
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=582
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=583
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=584
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=585
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=586
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=587
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=588
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=589
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=590
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=591
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=592
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=593
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=594
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=595
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=596
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=597
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=598
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=599
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=600
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=601
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=602
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=603
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=604
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=605
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=606
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=607
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=608
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=609
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=610
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=611
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=612
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=613
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=614
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=615
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=616
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=617
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=618
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=619
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=620
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=621
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=622
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=623
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=624
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=625
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=626
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=627
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=628
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=629
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=630
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=631
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=632
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=633
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=634
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=635
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=636
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=637
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=638
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=639
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=640
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=641
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=642
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=643
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=644
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=645
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=646
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=647
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=648
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=649
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=650
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=651
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=652
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=653
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=654
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=655
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=656
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=657
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=658
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=659
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=660
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=661
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=662
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=663
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=664
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=665
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=666
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=667
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=668
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=669
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=670
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=671
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=672
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=673
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=674
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=675
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=676
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=677
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=678
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=679
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=680
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=681
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=682
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=683
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=684
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=685
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=686
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=687
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=688
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=689
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=690
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=691
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=692
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=693
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=694
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=695
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=696
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=697
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=698
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=699
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=700
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=701
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=702
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=703
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=704
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=705
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=706
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=707
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=708
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=709
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=710
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=711
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=712
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=713
# http://wger.de/api/v2/ingredientweightunit/?format=json&page=714

# %%
len(df_all_ingredientsweight)
# Out:
# 14279

# %%
df_all_ingredientsweight.to_csv('ingredientweightunit.csv',sep=',', encoding='utf-8', index=False)

# delete existing data in the table
cursor.execute("DELETE FROM ingredientweightunit")
db_connection.commit()

# Now we will connect to the database and store equipments data
with open('ingredientweightunit.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip the header row.
    for row in reader:
        cursor.execute( "INSERT INTO ingredientweightunit VALUES (%s, %s, %s, %s, %s)", row)
db_connection.commit()
print("Data inserted successfully to ingredientweightunit table")
# Out:
# Data inserted successfully to ingredientweightunit table
